# %%
import matplotlib.pyplot as plt

# %%
tutor_results = [9, 7, 9, 10, 8]
lecturer_results = [10, 2]
coordinator_results = [7]


plt.bar([1,2,3,4,5], tutor_results)
plt.bar([6], coordinator_results)
plt.bar([7,8], lecturer_results)

plt.xlabel("Participant")
plt.ylabel("Perceived Valuability")
plt.show()
