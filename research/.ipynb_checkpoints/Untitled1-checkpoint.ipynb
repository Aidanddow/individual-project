# %%
headers = {
    "PRIVATE-TOKEN": "glpat-N7BrBvPV3CqT2Unn1-Zh"
}

# %%
def get_url(idd, request):
    return f"https://stgit.dcs.gla.ac.uk/api/v4//projects/{idd}/{request}"

# %%
import requests
url = f"https://stgit.dcs.gla.ac.uk/api/v4//groups"
response = requests.get(url, headers=headers)

# %%
import requests
import json


def get_all_projects(search_term):    
    ids = []
    for i in range(100):
        url = f"https://stgit.dcs.gla.ac.uk/api/v4//groups?page={i}&search={search_term}"
        response = requests.get(url, headers=headers)
        
        data = response.json()
        
        
        for i in response.json():
            print(f"{i.get('id')}: {i.get('full_path')}")
            
            proj_url = f"https://stgit.dcs.gla.ac.uk/api/v4//groups/{i.get('id')}/projects"
            res = requests.get(proj_url, headers=headers).json()
           
            if res:
                ids += [proj.get("id") for proj in res]
            
                for i in res:
                    print(f"    {i.get('id')}: {i.get('name')}")
            
            
            
        if not response.headers.get("x-next-page"): return ids
        
    return ids
        
print(get_all_projects("team-project-h"))
# Out:
# 2748: team-project-h/2021
# 8782: team-project-h/2022
# 2971: team-project-h/2021/cs20
#     2413: Team Project
#     2412: CS20 Dissertation
# 8810: team-project-h/2022/sh19
#     6030: SH19 main
#     6029: SH19 Dissertation
# 2747: team-project-h
#     2565: Project Allocations
# [2413, 2412, 6030, 6029, 2565]

# %%
url = f"https://stgit.dcs.gla.ac.uk/api/v4//projects?search=Team"
response = requests.get(url, headers=headers)
print(json.dumps(response.json(), indent=4))
# Out:
# [
#     {
#         "id": 2751,
#         "description": "",
#         "name": "team project",
#         "name_with_namespace": "Hang Wu / team project",
#         "path": "team-project",
#         "path_with_namespace": "2493535w/team-project",
#         "created_at": "2021-11-17T13:46:42.256+00:00",
#         "default_branch": "main",
#         "tag_list": [],
#         "topics": [],
#         "ssh_url_to_repo": "git@stgit.dcs.gla.ac.uk:2493535w/team-project.git",
#         "http_url_to_repo": "https://stgit.dcs.gla.ac.uk/2493535w/team-project.git",
#         "web_url": "https://stgit.dcs.gla.ac.uk/2493535w/team-project",
#         "readme_url": "https://stgit.dcs.gla.ac.uk/2493535w/team-project/-/blob/main/README.md",
#         "avatar_url": null,
#         "forks_count": 0,
#         "star_count": 0,
#         "last_activity_at": "2021-11-17T13:46:42.256+00:00",
#         "namespace": {
#             "id": 2940,
#             "name": "Hang Wu",
#             "path": "2493535w",
#             "kind": "user",
#             "full_path": "2493535w",
#             "parent_id": null,
#             "avatar_url": "https://secure.gravatar.com/avatar/ef5a1c5c426e28e26bfab11554523707?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2493535w"
#         },
#         "container_registry_image_prefix": "stgit.dcs.gla.ac.uk:5050/2493535w/team-project",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2751",
#             "issues": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2751/issues",
#             "merge_requests": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2751/merge_requests",
#             "repo_branches": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2751/repository/branches",
#             "labels": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2751/labels",
#             "events": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2751/events",
#             "members": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2751/members",
#             "cluster_agents": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2751/cluster_agents"
#         },
#         "packages_enabled": true,
#         "empty_repo": false,
#         "archived": false,
#         "visibility": "internal",
#         "owner": {
#             "id": 2028,
#             "username": "2493535w",
#             "name": "Hang Wu",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/ef5a1c5c426e28e26bfab11554523707?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2493535w"
#         },
#         "resolve_outdated_diff_discussions": false,
#         "container_expiration_policy": {
#             "cadence": "1d",
#             "enabled": false,
#             "keep_n": 10,
#             "older_than": "90d",
#             "name_regex": ".*",
#             "name_regex_keep": null,
#             "next_run_at": "2021-11-18T13:46:42.316+00:00"
#         },
#         "issues_enabled": true,
#         "merge_requests_enabled": true,
#         "wiki_enabled": true,
#         "jobs_enabled": true,
#         "snippets_enabled": true,
#         "container_registry_enabled": true,
#         "service_desk_enabled": false,
#         "can_create_merge_request_in": true,
#         "issues_access_level": "enabled",
#         "repository_access_level": "enabled",
#         "merge_requests_access_level": "enabled",
#         "forking_access_level": "enabled",
#         "wiki_access_level": "enabled",
#         "builds_access_level": "enabled",
#         "snippets_access_level": "enabled",
#         "pages_access_level": "private",
#         "operations_access_level": "enabled",
#         "analytics_access_level": "enabled",
#         "container_registry_access_level": "enabled",
#         "security_and_compliance_access_level": "private",
#         "emails_disabled": null,
#         "shared_runners_enabled": true,
#         "lfs_enabled": true,
#         "creator_id": 2028,
#         "import_status": "none",
#         "open_issues_count": 0,
#         "ci_default_git_depth": 50,
#         "ci_forward_deployment_enabled": true,
#         "ci_job_token_scope_enabled": false,
#         "ci_separated_caches": true,
#         "ci_opt_in_jwt": false,
#         "ci_allow_fork_pipelines_to_run_in_parent_project": true,
#         "public_jobs": true,
#         "build_timeout": 3600,
#         "auto_cancel_pending_pipelines": "enabled",
#         "ci_config_path": "",
#         "shared_with_groups": [],
#         "only_allow_merge_if_pipeline_succeeds": false,
#         "allow_merge_on_skipped_pipeline": null,
#         "restrict_user_defined_variables": false,
#         "request_access_enabled": true,
#         "only_allow_merge_if_all_discussions_are_resolved": false,
#         "remove_source_branch_after_merge": true,
#         "printing_merge_request_link_enabled": true,
#         "merge_method": "merge",
#         "squash_option": "default_off",
#         "enforce_auth_checks_on_uploads": true,
#         "suggestion_commit_message": null,
#         "merge_commit_template": null,
#         "squash_commit_template": null,
#         "auto_devops_enabled": true,
#         "auto_devops_deploy_strategy": "continuous",
#         "autoclose_referenced_issues": true,
#         "keep_latest_artifact": true,
#         "runner_token_expiration_interval": null,
#         "permissions": {
#             "project_access": null,
#             "group_access": null
#         }
#     },
#     {
#         "id": 2413,
#         "description": "",
#         "name": "Team Project",
#         "name_with_namespace": "Team Project H / 2021 / CS20 / Team Project",
#         "path": "cs20-main",
#         "path_with_namespace": "team-project-h/2021/cs20/cs20-main",
#         "created_at": "2021-09-28T19:09:59.849+01:00",
#         "default_branch": "developer",
#         "tag_list": [],
#         "topics": [],
#         "ssh_url_to_repo": "git@stgit.dcs.gla.ac.uk:team-project-h/2021/cs20/cs20-main.git",
#         "http_url_to_repo": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main.git",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main",
#         "readme_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/blob/developer/README.md",
#         "avatar_url": null,
#         "forks_count": 0,
#         "star_count": 2,
#         "last_activity_at": "2022-04-04T13:21:08.830+01:00",
#         "namespace": {
#             "id": 2971,
#             "name": "CS20",
#             "path": "cs20",
#             "kind": "group",
#             "full_path": "team-project-h/2021/cs20",
#             "parent_id": 2748,
#             "avatar_url": null,
#             "web_url": "https://stgit.dcs.gla.ac.uk/groups/team-project-h/2021/cs20"
#         },
#         "container_registry_image_prefix": "stgit.dcs.gla.ac.uk:5050/team-project-h/2021/cs20/cs20-main",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "issues": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues",
#             "merge_requests": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/merge_requests",
#             "repo_branches": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/repository/branches",
#             "labels": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/labels",
#             "events": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/events",
#             "members": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/members",
#             "cluster_agents": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/cluster_agents"
#         },
#         "packages_enabled": true,
#         "empty_repo": false,
#         "archived": false,
#         "visibility": "private",
#         "resolve_outdated_diff_discussions": false,
#         "container_expiration_policy": {
#             "cadence": "1d",
#             "enabled": false,
#             "keep_n": 10,
#             "older_than": "90d",
#             "name_regex": ".*",
#             "name_regex_keep": null,
#             "next_run_at": "2021-09-29T19:09:59.868+01:00"
#         },
#         "issues_enabled": true,
#         "merge_requests_enabled": true,
#         "wiki_enabled": true,
#         "jobs_enabled": true,
#         "snippets_enabled": true,
#         "container_registry_enabled": true,
#         "service_desk_enabled": false,
#         "service_desk_address": null,
#         "can_create_merge_request_in": true,
#         "issues_access_level": "enabled",
#         "repository_access_level": "enabled",
#         "merge_requests_access_level": "enabled",
#         "forking_access_level": "enabled",
#         "wiki_access_level": "enabled",
#         "builds_access_level": "enabled",
#         "snippets_access_level": "enabled",
#         "pages_access_level": "private",
#         "operations_access_level": "enabled",
#         "analytics_access_level": "enabled",
#         "container_registry_access_level": "enabled",
#         "security_and_compliance_access_level": "private",
#         "emails_disabled": null,
#         "shared_runners_enabled": true,
#         "lfs_enabled": true,
#         "creator_id": 1933,
#         "import_url": null,
#         "import_type": null,
#         "import_status": "none",
#         "open_issues_count": 0,
#         "ci_default_git_depth": 50,
#         "ci_forward_deployment_enabled": true,
#         "ci_job_token_scope_enabled": false,
#         "ci_separated_caches": true,
#         "ci_opt_in_jwt": false,
#         "ci_allow_fork_pipelines_to_run_in_parent_project": true,
#         "public_jobs": true,
#         "build_timeout": 3600,
#         "auto_cancel_pending_pipelines": "enabled",
#         "ci_config_path": "",
#         "shared_with_groups": [],
#         "only_allow_merge_if_pipeline_succeeds": false,
#         "allow_merge_on_skipped_pipeline": false,
#         "restrict_user_defined_variables": false,
#         "request_access_enabled": true,
#         "only_allow_merge_if_all_discussions_are_resolved": false,
#         "remove_source_branch_after_merge": true,
#         "printing_merge_request_link_enabled": true,
#         "merge_method": "ff",
#         "squash_option": "default_off",
#         "enforce_auth_checks_on_uploads": true,
#         "suggestion_commit_message": "",
#         "merge_commit_template": null,
#         "squash_commit_template": null,
#         "auto_devops_enabled": false,
#         "auto_devops_deploy_strategy": "continuous",
#         "autoclose_referenced_issues": true,
#         "keep_latest_artifact": true,
#         "runner_token_expiration_interval": null,
#         "permissions": {
#             "project_access": null,
#             "group_access": {
#                 "access_level": 50,
#                 "notification_level": 3
#             }
#         }
#     },
#     {
#         "id": 2288,
#         "description": "",
#         "name": "ITSD-TeamProject",
#         "name_with_namespace": "Yawen Hou / ITSD-TeamProject",
#         "path": "itsd-teamproject",
#         "path_with_namespace": "2576132h/itsd-teamproject",
#         "created_at": "2021-07-04T13:24:05.782+01:00",
#         "default_branch": "master",
#         "tag_list": [],
#         "topics": [],
#         "ssh_url_to_repo": "git@stgit.dcs.gla.ac.uk:2576132h/itsd-teamproject.git",
#         "http_url_to_repo": "https://stgit.dcs.gla.ac.uk/2576132h/itsd-teamproject.git",
#         "web_url": "https://stgit.dcs.gla.ac.uk/2576132h/itsd-teamproject",
#         "readme_url": "https://stgit.dcs.gla.ac.uk/2576132h/itsd-teamproject/-/blob/master/README.md",
#         "avatar_url": null,
#         "forks_count": 0,
#         "star_count": 0,
#         "last_activity_at": "2021-07-04T13:24:05.782+01:00",
#         "namespace": {
#             "id": 2426,
#             "name": "Yawen Hou",
#             "path": "2576132h",
#             "kind": "user",
#             "full_path": "2576132h",
#             "parent_id": null,
#             "avatar_url": "https://secure.gravatar.com/avatar/b45a209b782f06c7363e9348458b666a?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2576132h"
#         },
#         "container_registry_image_prefix": "stgit.dcs.gla.ac.uk:5050/2576132h/itsd-teamproject",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2288",
#             "issues": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2288/issues",
#             "merge_requests": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2288/merge_requests",
#             "repo_branches": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2288/repository/branches",
#             "labels": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2288/labels",
#             "events": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2288/events",
#             "members": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2288/members",
#             "cluster_agents": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2288/cluster_agents"
#         },
#         "packages_enabled": true,
#         "empty_repo": false,
#         "archived": false,
#         "visibility": "public",
#         "owner": {
#             "id": 1629,
#             "username": "2576132h",
#             "name": "Yawen Hou",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b45a209b782f06c7363e9348458b666a?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2576132h"
#         },
#         "resolve_outdated_diff_discussions": false,
#         "container_expiration_policy": {
#             "cadence": "1d",
#             "enabled": false,
#             "keep_n": 10,
#             "older_than": "90d",
#             "name_regex": ".*",
#             "name_regex_keep": null,
#             "next_run_at": "2021-07-05T13:24:05.875+01:00"
#         },
#         "issues_enabled": true,
#         "merge_requests_enabled": true,
#         "wiki_enabled": true,
#         "jobs_enabled": true,
#         "snippets_enabled": true,
#         "container_registry_enabled": true,
#         "service_desk_enabled": false,
#         "can_create_merge_request_in": true,
#         "issues_access_level": "enabled",
#         "repository_access_level": "enabled",
#         "merge_requests_access_level": "enabled",
#         "forking_access_level": "enabled",
#         "wiki_access_level": "enabled",
#         "builds_access_level": "enabled",
#         "snippets_access_level": "enabled",
#         "pages_access_level": "enabled",
#         "operations_access_level": "enabled",
#         "analytics_access_level": "enabled",
#         "container_registry_access_level": "enabled",
#         "security_and_compliance_access_level": "private",
#         "emails_disabled": null,
#         "shared_runners_enabled": true,
#         "lfs_enabled": true,
#         "creator_id": 1629,
#         "forked_from_project": {
#             "id": 2233,
#             "description": "",
#             "name": "ITSD-TeamProject",
#             "name_with_namespace": "Yiwei Hu / ITSD-TeamProject",
#             "path": "itsd-teamproject",
#             "path_with_namespace": "2588652h/itsd-teamproject",
#             "created_at": "2021-06-26T21:09:49.255+01:00",
#             "default_branch": "master",
#             "tag_list": [],
#             "topics": [],
#             "ssh_url_to_repo": "git@stgit.dcs.gla.ac.uk:2588652h/itsd-teamproject.git",
#             "http_url_to_repo": "https://stgit.dcs.gla.ac.uk/2588652h/itsd-teamproject.git",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2588652h/itsd-teamproject",
#             "readme_url": "https://stgit.dcs.gla.ac.uk/2588652h/itsd-teamproject/-/blob/master/README.md",
#             "avatar_url": null,
#             "forks_count": 1,
#             "star_count": 0,
#             "last_activity_at": "2021-08-01T00:10:27.390+01:00",
#             "namespace": {
#                 "id": 2428,
#                 "name": "Yiwei Hu",
#                 "path": "2588652h",
#                 "kind": "user",
#                 "full_path": "2588652h",
#                 "parent_id": null,
#                 "avatar_url": "https://secure.gravatar.com/avatar/231eda6cab9ce0d9260ef266e705c0df?s=80&d=identicon",
#                 "web_url": "https://stgit.dcs.gla.ac.uk/2588652h"
#             }
#         },
#         "mr_default_target_self": false,
#         "import_status": "finished",
#         "open_issues_count": 0,
#         "ci_default_git_depth": 50,
#         "ci_forward_deployment_enabled": true,
#         "ci_job_token_scope_enabled": false,
#         "ci_separated_caches": true,
#         "ci_opt_in_jwt": false,
#         "ci_allow_fork_pipelines_to_run_in_parent_project": true,
#         "public_jobs": true,
#         "build_timeout": 3600,
#         "auto_cancel_pending_pipelines": "enabled",
#         "ci_config_path": "",
#         "shared_with_groups": [],
#         "only_allow_merge_if_pipeline_succeeds": false,
#         "allow_merge_on_skipped_pipeline": null,
#         "restrict_user_defined_variables": false,
#         "request_access_enabled": true,
#         "only_allow_merge_if_all_discussions_are_resolved": false,
#         "remove_source_branch_after_merge": true,
#         "printing_merge_request_link_enabled": true,
#         "merge_method": "merge",
#         "squash_option": "default_off",
#         "enforce_auth_checks_on_uploads": true,
#         "suggestion_commit_message": null,
#         "merge_commit_template": null,
#         "squash_commit_template": null,
#         "auto_devops_enabled": true,
#         "auto_devops_deploy_strategy": "continuous",
#         "autoclose_referenced_issues": true,
#         "keep_latest_artifact": true,
#         "runner_token_expiration_interval": null,
#         "permissions": {
#             "project_access": null,
#             "group_access": null
#         }
#     },
#     {
#         "id": 2233,
#         "description": "",
#         "name": "ITSD-TeamProject",
#         "name_with_namespace": "Yiwei Hu / ITSD-TeamProject",
#         "path": "itsd-teamproject",
#         "path_with_namespace": "2588652h/itsd-teamproject",
#         "created_at": "2021-06-26T21:09:49.255+01:00",
#         "default_branch": "master",
#         "tag_list": [],
#         "topics": [],
#         "ssh_url_to_repo": "git@stgit.dcs.gla.ac.uk:2588652h/itsd-teamproject.git",
#         "http_url_to_repo": "https://stgit.dcs.gla.ac.uk/2588652h/itsd-teamproject.git",
#         "web_url": "https://stgit.dcs.gla.ac.uk/2588652h/itsd-teamproject",
#         "readme_url": "https://stgit.dcs.gla.ac.uk/2588652h/itsd-teamproject/-/blob/master/README.md",
#         "avatar_url": null,
#         "forks_count": 1,
#         "star_count": 0,
#         "last_activity_at": "2021-08-01T00:10:27.390+01:00",
#         "namespace": {
#             "id": 2428,
#             "name": "Yiwei Hu",
#             "path": "2588652h",
#             "kind": "user",
#             "full_path": "2588652h",
#             "parent_id": null,
#             "avatar_url": "https://secure.gravatar.com/avatar/231eda6cab9ce0d9260ef266e705c0df?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2588652h"
#         },
#         "container_registry_image_prefix": "stgit.dcs.gla.ac.uk:5050/2588652h/itsd-teamproject",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2233",
#             "issues": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2233/issues",
#             "merge_requests": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2233/merge_requests",
#             "repo_branches": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2233/repository/branches",
#             "labels": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2233/labels",
#             "events": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2233/events",
#             "members": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2233/members",
#             "cluster_agents": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2233/cluster_agents"
#         },
#         "packages_enabled": true,
#         "empty_repo": false,
#         "archived": false,
#         "visibility": "public",
#         "owner": {
#             "id": 1630,
#             "username": "2588652h",
#             "name": "Yiwei Hu",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/231eda6cab9ce0d9260ef266e705c0df?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2588652h"
#         },
#         "resolve_outdated_diff_discussions": false,
#         "container_expiration_policy": {
#             "cadence": "1d",
#             "enabled": false,
#             "keep_n": 10,
#             "older_than": "90d",
#             "name_regex": ".*",
#             "name_regex_keep": null,
#             "next_run_at": "2021-06-27T21:09:49.403+01:00"
#         },
#         "issues_enabled": true,
#         "merge_requests_enabled": true,
#         "wiki_enabled": true,
#         "jobs_enabled": true,
#         "snippets_enabled": true,
#         "container_registry_enabled": true,
#         "service_desk_enabled": false,
#         "can_create_merge_request_in": true,
#         "issues_access_level": "enabled",
#         "repository_access_level": "enabled",
#         "merge_requests_access_level": "enabled",
#         "forking_access_level": "enabled",
#         "wiki_access_level": "enabled",
#         "builds_access_level": "enabled",
#         "snippets_access_level": "enabled",
#         "pages_access_level": "private",
#         "operations_access_level": "enabled",
#         "analytics_access_level": "enabled",
#         "container_registry_access_level": "enabled",
#         "security_and_compliance_access_level": "private",
#         "emails_disabled": false,
#         "shared_runners_enabled": true,
#         "lfs_enabled": true,
#         "creator_id": 1630,
#         "import_status": "none",
#         "open_issues_count": 0,
#         "ci_default_git_depth": 50,
#         "ci_forward_deployment_enabled": true,
#         "ci_job_token_scope_enabled": false,
#         "ci_separated_caches": true,
#         "ci_opt_in_jwt": false,
#         "ci_allow_fork_pipelines_to_run_in_parent_project": true,
#         "public_jobs": true,
#         "build_timeout": 3600,
#         "auto_cancel_pending_pipelines": "enabled",
#         "ci_config_path": "",
#         "shared_with_groups": [],
#         "only_allow_merge_if_pipeline_succeeds": false,
#         "allow_merge_on_skipped_pipeline": null,
#         "restrict_user_defined_variables": false,
#         "request_access_enabled": true,
#         "only_allow_merge_if_all_discussions_are_resolved": false,
#         "remove_source_branch_after_merge": true,
#         "printing_merge_request_link_enabled": true,
#         "merge_method": "merge",
#         "squash_option": "default_off",
#         "enforce_auth_checks_on_uploads": true,
#         "suggestion_commit_message": null,
#         "merge_commit_template": null,
#         "squash_commit_template": null,
#         "auto_devops_enabled": true,
#         "auto_devops_deploy_strategy": "continuous",
#         "autoclose_referenced_issues": true,
#         "keep_latest_artifact": true,
#         "runner_token_expiration_interval": null,
#         "permissions": {
#             "project_access": null,
#             "group_access": null
#         }
#     },
#     {
#         "id": 2072,
#         "description": "",
#         "name": "TeamProject",
#         "name_with_namespace": "Brian Edward Suhs / TeamProject",
#         "path": "teamproject",
#         "path_with_namespace": "2583968s/teamproject",
#         "created_at": "2021-02-14T12:15:49.934+00:00",
#         "default_branch": "master",
#         "tag_list": [],
#         "topics": [],
#         "ssh_url_to_repo": "git@stgit.dcs.gla.ac.uk:2583968s/teamproject.git",
#         "http_url_to_repo": "https://stgit.dcs.gla.ac.uk/2583968s/teamproject.git",
#         "web_url": "https://stgit.dcs.gla.ac.uk/2583968s/teamproject",
#         "readme_url": "https://stgit.dcs.gla.ac.uk/2583968s/teamproject/-/blob/master/README.md",
#         "avatar_url": null,
#         "forks_count": 0,
#         "star_count": 0,
#         "last_activity_at": "2021-02-26T13:45:46.515+00:00",
#         "namespace": {
#             "id": 2294,
#             "name": "Brian Edward Suhs",
#             "path": "2583968s",
#             "kind": "user",
#             "full_path": "2583968s",
#             "parent_id": null,
#             "avatar_url": "https://secure.gravatar.com/avatar/87f58661e6f803616606e50fa0a2a67c?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2583968s"
#         },
#         "container_registry_image_prefix": "stgit.dcs.gla.ac.uk:5050/2583968s/teamproject",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2072",
#             "issues": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2072/issues",
#             "merge_requests": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2072/merge_requests",
#             "repo_branches": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2072/repository/branches",
#             "labels": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2072/labels",
#             "events": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2072/events",
#             "members": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2072/members",
#             "cluster_agents": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2072/cluster_agents"
#         },
#         "packages_enabled": true,
#         "empty_repo": false,
#         "archived": false,
#         "visibility": "internal",
#         "owner": {
#             "id": 1530,
#             "username": "2583968s",
#             "name": "Brian Edward Suhs",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/87f58661e6f803616606e50fa0a2a67c?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2583968s"
#         },
#         "resolve_outdated_diff_discussions": false,
#         "container_expiration_policy": {
#             "cadence": "1d",
#             "enabled": false,
#             "keep_n": 10,
#             "older_than": "90d",
#             "name_regex": null,
#             "name_regex_keep": null,
#             "next_run_at": "2021-06-11T14:50:12.270+01:00"
#         },
#         "issues_enabled": true,
#         "merge_requests_enabled": true,
#         "wiki_enabled": true,
#         "jobs_enabled": true,
#         "snippets_enabled": true,
#         "container_registry_enabled": true,
#         "service_desk_enabled": false,
#         "can_create_merge_request_in": true,
#         "issues_access_level": "enabled",
#         "repository_access_level": "enabled",
#         "merge_requests_access_level": "enabled",
#         "forking_access_level": "enabled",
#         "wiki_access_level": "enabled",
#         "builds_access_level": "enabled",
#         "snippets_access_level": "enabled",
#         "pages_access_level": "private",
#         "operations_access_level": "enabled",
#         "analytics_access_level": "enabled",
#         "container_registry_access_level": "enabled",
#         "security_and_compliance_access_level": "private",
#         "emails_disabled": null,
#         "shared_runners_enabled": true,
#         "lfs_enabled": true,
#         "creator_id": 1530,
#         "import_status": "none",
#         "open_issues_count": 1,
#         "ci_default_git_depth": 50,
#         "ci_forward_deployment_enabled": true,
#         "ci_job_token_scope_enabled": false,
#         "ci_separated_caches": true,
#         "ci_opt_in_jwt": false,
#         "ci_allow_fork_pipelines_to_run_in_parent_project": true,
#         "public_jobs": true,
#         "build_timeout": 3600,
#         "auto_cancel_pending_pipelines": "enabled",
#         "ci_config_path": "",
#         "shared_with_groups": [],
#         "only_allow_merge_if_pipeline_succeeds": false,
#         "allow_merge_on_skipped_pipeline": null,
#         "restrict_user_defined_variables": false,
#         "request_access_enabled": true,
#         "only_allow_merge_if_all_discussions_are_resolved": false,
#         "remove_source_branch_after_merge": true,
#         "printing_merge_request_link_enabled": true,
#         "merge_method": "merge",
#         "squash_option": "default_off",
#         "enforce_auth_checks_on_uploads": true,
#         "suggestion_commit_message": null,
#         "merge_commit_template": null,
#         "squash_commit_template": null,
#         "auto_devops_enabled": true,
#         "auto_devops_deploy_strategy": "continuous",
#         "autoclose_referenced_issues": true,
#         "keep_latest_artifact": true,
#         "runner_token_expiration_interval": null,
#         "permissions": {
#             "project_access": null,
#             "group_access": null
#         }
#     },
#     {
#         "id": 1490,
#         "description": "",
#         "name": "empty-django-for-team3",
#         "name_with_namespace": "Ming Ho Wu / empty-django-for-team3",
#         "path": "empty-django-for-charles",
#         "path_with_namespace": "2133861w/empty-django-for-charles",
#         "created_at": "2020-01-09T11:33:24.480+00:00",
#         "default_branch": "master",
#         "tag_list": [],
#         "topics": [],
#         "ssh_url_to_repo": "git@stgit.dcs.gla.ac.uk:2133861w/empty-django-for-charles.git",
#         "http_url_to_repo": "https://stgit.dcs.gla.ac.uk/2133861w/empty-django-for-charles.git",
#         "web_url": "https://stgit.dcs.gla.ac.uk/2133861w/empty-django-for-charles",
#         "readme_url": "https://stgit.dcs.gla.ac.uk/2133861w/empty-django-for-charles/-/blob/master/README.md",
#         "avatar_url": null,
#         "forks_count": 0,
#         "star_count": 0,
#         "last_activity_at": "2020-01-09T15:26:02.125+00:00",
#         "namespace": {
#             "id": 465,
#             "name": "Ming Ho Wu",
#             "path": "2133861w",
#             "kind": "user",
#             "full_path": "2133861w",
#             "parent_id": null,
#             "avatar_url": "https://secure.gravatar.com/avatar/e87266b03455969949e608f11760d35c?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2133861w"
#         },
#         "container_registry_image_prefix": "stgit.dcs.gla.ac.uk:5050/2133861w/empty-django-for-charles",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/1490",
#             "issues": "https://stgit.dcs.gla.ac.uk/api/v4/projects/1490/issues",
#             "merge_requests": "https://stgit.dcs.gla.ac.uk/api/v4/projects/1490/merge_requests",
#             "repo_branches": "https://stgit.dcs.gla.ac.uk/api/v4/projects/1490/repository/branches",
#             "labels": "https://stgit.dcs.gla.ac.uk/api/v4/projects/1490/labels",
#             "events": "https://stgit.dcs.gla.ac.uk/api/v4/projects/1490/events",
#             "members": "https://stgit.dcs.gla.ac.uk/api/v4/projects/1490/members",
#             "cluster_agents": "https://stgit.dcs.gla.ac.uk/api/v4/projects/1490/cluster_agents"
#         },
#         "packages_enabled": null,
#         "empty_repo": false,
#         "archived": false,
#         "visibility": "public",
#         "owner": {
#             "id": 374,
#             "username": "2133861w",
#             "name": "Ming Ho Wu",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/e87266b03455969949e608f11760d35c?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2133861w"
#         },
#         "resolve_outdated_diff_discussions": false,
#         "container_expiration_policy": {
#             "cadence": "7d",
#             "enabled": false,
#             "keep_n": null,
#             "older_than": null,
#             "name_regex": null,
#             "name_regex_keep": null,
#             "next_run_at": null
#         },
#         "issues_enabled": true,
#         "merge_requests_enabled": true,
#         "wiki_enabled": true,
#         "jobs_enabled": true,
#         "snippets_enabled": true,
#         "container_registry_enabled": true,
#         "service_desk_enabled": false,
#         "can_create_merge_request_in": true,
#         "issues_access_level": "enabled",
#         "repository_access_level": "enabled",
#         "merge_requests_access_level": "enabled",
#         "forking_access_level": "enabled",
#         "wiki_access_level": "enabled",
#         "builds_access_level": "enabled",
#         "snippets_access_level": "enabled",
#         "pages_access_level": "enabled",
#         "operations_access_level": "enabled",
#         "analytics_access_level": "enabled",
#         "container_registry_access_level": "enabled",
#         "security_and_compliance_access_level": "private",
#         "emails_disabled": null,
#         "shared_runners_enabled": true,
#         "lfs_enabled": true,
#         "creator_id": 374,
#         "import_status": "none",
#         "open_issues_count": 0,
#         "ci_default_git_depth": 50,
#         "ci_forward_deployment_enabled": null,
#         "ci_job_token_scope_enabled": false,
#         "ci_separated_caches": true,
#         "ci_opt_in_jwt": false,
#         "ci_allow_fork_pipelines_to_run_in_parent_project": true,
#         "public_jobs": true,
#         "build_timeout": 3600,
#         "auto_cancel_pending_pipelines": "enabled",
#         "ci_config_path": null,
#         "shared_with_groups": [],
#         "only_allow_merge_if_pipeline_succeeds": false,
#         "allow_merge_on_skipped_pipeline": null,
#         "restrict_user_defined_variables": false,
#         "request_access_enabled": true,
#         "only_allow_merge_if_all_discussions_are_resolved": false,
#         "remove_source_branch_after_merge": true,
#         "printing_merge_request_link_enabled": true,
#         "merge_method": "merge",
#         "squash_option": "default_off",
#         "enforce_auth_checks_on_uploads": true,
#         "suggestion_commit_message": null,
#         "merge_commit_template": null,
#         "squash_commit_template": null,
#         "auto_devops_enabled": false,
#         "auto_devops_deploy_strategy": "continuous",
#         "autoclose_referenced_issues": true,
#         "keep_latest_artifact": true,
#         "runner_token_expiration_interval": null,
#         "permissions": {
#             "project_access": null,
#             "group_access": null
#         }
#     },
#     {
#         "id": 985,
#         "description": "kei bike team project working repo.",
#         "name": "bike_prj",
#         "name_with_namespace": "Kei kuan To / bike_prj",
#         "path": "bike_prj",
#         "path_with_namespace": "2498456t/bike_prj",
#         "created_at": "2019-10-10T21:21:38.539+01:00",
#         "tag_list": [],
#         "topics": [],
#         "ssh_url_to_repo": "git@stgit.dcs.gla.ac.uk:2498456t/bike_prj.git",
#         "http_url_to_repo": "https://stgit.dcs.gla.ac.uk/2498456t/bike_prj.git",
#         "web_url": "https://stgit.dcs.gla.ac.uk/2498456t/bike_prj",
#         "readme_url": "https://stgit.dcs.gla.ac.uk/2498456t/bike_prj/-/blob/master/README.md",
#         "avatar_url": null,
#         "forks_count": 0,
#         "star_count": 0,
#         "last_activity_at": "2019-11-03T21:53:13.333+00:00",
#         "namespace": {
#             "id": 710,
#             "name": "Kei kuan To",
#             "path": "2498456t",
#             "kind": "user",
#             "full_path": "2498456t",
#             "parent_id": null,
#             "avatar_url": "https://secure.gravatar.com/avatar/4f4f50700daf7a6717d3186fadce7cbc?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2498456t"
#         },
#         "container_registry_image_prefix": "stgit.dcs.gla.ac.uk:5050/2498456t/bike_prj",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/985",
#             "issues": "https://stgit.dcs.gla.ac.uk/api/v4/projects/985/issues",
#             "repo_branches": "https://stgit.dcs.gla.ac.uk/api/v4/projects/985/repository/branches",
#             "labels": "https://stgit.dcs.gla.ac.uk/api/v4/projects/985/labels",
#             "events": "https://stgit.dcs.gla.ac.uk/api/v4/projects/985/events",
#             "members": "https://stgit.dcs.gla.ac.uk/api/v4/projects/985/members",
#             "cluster_agents": "https://stgit.dcs.gla.ac.uk/api/v4/projects/985/cluster_agents"
#         },
#         "packages_enabled": null,
#         "empty_repo": false,
#         "archived": false,
#         "visibility": "internal",
#         "owner": {
#             "id": 567,
#             "username": "2498456t",
#             "name": "Kei kuan To",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/4f4f50700daf7a6717d3186fadce7cbc?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2498456t"
#         },
#         "resolve_outdated_diff_discussions": false,
#         "issues_enabled": true,
#         "merge_requests_enabled": false,
#         "wiki_enabled": true,
#         "jobs_enabled": false,
#         "snippets_enabled": true,
#         "container_registry_enabled": true,
#         "service_desk_enabled": false,
#         "can_create_merge_request_in": false,
#         "issues_access_level": "enabled",
#         "repository_access_level": "private",
#         "merge_requests_access_level": "disabled",
#         "forking_access_level": "enabled",
#         "wiki_access_level": "enabled",
#         "builds_access_level": "disabled",
#         "snippets_access_level": "enabled",
#         "pages_access_level": "private",
#         "operations_access_level": "enabled",
#         "analytics_access_level": "enabled",
#         "container_registry_access_level": "enabled",
#         "security_and_compliance_access_level": "private",
#         "emails_disabled": false,
#         "shared_runners_enabled": true,
#         "lfs_enabled": true,
#         "creator_id": 567,
#         "import_status": "none",
#         "open_issues_count": 0,
#         "ci_default_git_depth": 50,
#         "ci_forward_deployment_enabled": null,
#         "ci_job_token_scope_enabled": false,
#         "ci_separated_caches": true,
#         "ci_opt_in_jwt": false,
#         "ci_allow_fork_pipelines_to_run_in_parent_project": true,
#         "public_jobs": true,
#         "build_timeout": 3600,
#         "auto_cancel_pending_pipelines": "enabled",
#         "shared_with_groups": [],
#         "only_allow_merge_if_pipeline_succeeds": false,
#         "allow_merge_on_skipped_pipeline": null,
#         "restrict_user_defined_variables": false,
#         "request_access_enabled": true,
#         "only_allow_merge_if_all_discussions_are_resolved": false,
#         "remove_source_branch_after_merge": null,
#         "printing_merge_request_link_enabled": true,
#         "merge_method": "merge",
#         "squash_option": "default_off",
#         "enforce_auth_checks_on_uploads": true,
#         "suggestion_commit_message": null,
#         "merge_commit_template": null,
#         "squash_commit_template": null,
#         "auto_devops_enabled": true,
#         "auto_devops_deploy_strategy": "continuous",
#         "autoclose_referenced_issues": true,
#         "keep_latest_artifact": true,
#         "runner_token_expiration_interval": null,
#         "permissions": {
#             "project_access": null,
#             "group_access": null
#         }
#     }
# ]

# %%
get_url(2413, "")
# Out:
# 'https://stgit.dcs.gla.ac.uk/api/v4//projects/2413/'

# %%
import json, datetime
import matplotlib.pyplot as plt

def get_num_pages(id, per_page):
    i = 1
    while True:
        response = get_commits_page(id, i, per_page)
        if not response.headers.get("x-next-page"): return i
        i+=1
        
def get_commits_page(id, page, per_page):
    url = get_url(id, f"repository/commits?per_page={per_page}&page={page}")
    response = requests.get(url, headers=headers)
#     print(json.dumps(dict(response.headers), indent=4))
    return response

def get_num_commits(id, per_page):

    t1 = datetime.datetime.now()

    full_pages = get_num_pages(id, per_page)
    last_page = get_commits_page(id, full_pages, per_page)
    
    total = ((full_pages-1) * per_page) + len(last_page.json())
    # print(last_page.json())

    t2 = datetime.datetime.now()
    
    time_taken = float(f"{(t2-t1).seconds}.{(t2-t1).microseconds}")

    print(f"per_page: {per_page}")
    print(f"Pages full = {full_pages-1}, last_page = {len(last_page.json())}")
    print(f"Total size = {total}")
    print(f"Time Taken: {time_taken}s")
    print()
    return time_taken
    
times = []
per_pages = [40, 50, 60,70,80,90,100]
for per_page in per_pages:
    times.append(get_num_commits(2413, per_page))
    
plt.plot(per_pages, times)
# Out:
# per_page: 40
# Pages full = 6, last_page = 23
# Total size = 263
# Time Taken: 2.92291s
#
# per_page: 50
# Pages full = 5, last_page = 13
# Total size = 263
# Time Taken: 1.840495s
#
# per_page: 60
# Pages full = 4, last_page = 23
# Total size = 263
# Time Taken: 1.638272s
#
# per_page: 70
# Pages full = 3, last_page = 53
# Total size = 263
# Time Taken: 1.457951s
#
# per_page: 80
# Pages full = 3, last_page = 23
# Total size = 263
# Time Taken: 1.431923s
#
# per_page: 90
# Pages full = 2, last_page = 83
# Total size = 263
# Time Taken: 1.156308s
#
# per_page: 100
# Pages full = 2, last_page = 63
# Total size = 263
# Time Taken: 1.182334s
