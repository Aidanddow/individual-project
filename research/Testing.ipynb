# %%
headers = {
    "PRIVATE-TOKEN": "glpat-N7BrBvPV3CqT2Unn1-Zh"
}

# %%
def get_url(idd, request):
    return f"https://stgit.dcs.gla.ac.uk/api/v4//projects/{idd}/{request}"

# %%
import requests, json
url = f"https://stgit.dcs.gla.ac.uk/api/v4//projects/6030/repository/commits?page=1&per_page=20"
# repository/commits/b4944a37e0e77737670992662d0796ce1b7b77eb/
response = requests.get(url, headers=headers)
data = response.json()

# print(response.headers)
print(json.dumps(data, indent=4))

# for i,j in response.headers.items():
#     print(i,j)
# Out:
# [
#     {
#         "id": "61b181c0eae0ad1e99ad5ad942d120ff9f4168b0",
#         "short_id": "61b181c0",
#         "created_at": "2022-11-16T21:13:14.000+08:00",
#         "parent_ids": [
#             "f00cff58c9f236553b82f360bfc020f335bc42cd"
#         ],
#         "title": "first",
#         "message": "first\n",
#         "author_name": "MingyangChen",
#         "author_email": "2512330C@student.gla.ac.uk",
#         "authored_date": "2022-11-16T21:13:14.000+08:00",
#         "committer_name": "MingyangChen",
#         "committer_email": "2512330C@student.gla.ac.uk",
#         "committed_date": "2022-11-16T21:13:14.000+08:00",
#         "trailers": {},
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2022/sh19/sh19-main/-/commit/61b181c0eae0ad1e99ad5ad942d120ff9f4168b0"
#     },
#     {
#         "id": "f00cff58c9f236553b82f360bfc020f335bc42cd",
#         "short_id": "f00cff58",
#         "created_at": "2022-10-27T13:25:27.000+01:00",
#         "parent_ids": [
#             "53fa19286469613534f55e3691e9bc7dc87c4437"
#         ],
#         "title": "Sensor Starting Files",
#         "message": "Sensor Starting Files\n",
#         "author_name": "kylethmas",
#         "author_email": "kyle2010thomas@gmail.com",
#         "authored_date": "2022-10-27T13:25:27.000+01:00",
#         "committer_name": "kylethmas",
#         "committer_email": "kyle2010thomas@gmail.com",
#         "committed_date": "2022-10-27T13:25:27.000+01:00",
#         "trailers": {},
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2022/sh19/sh19-main/-/commit/f00cff58c9f236553b82f360bfc020f335bc42cd"
#     },
#     {
#         "id": "53fa19286469613534f55e3691e9bc7dc87c4437",
#         "short_id": "53fa1928",
#         "created_at": "2022-09-28T12:11:27.000+01:00",
#         "parent_ids": [
#             "7bef5e697d7ed2cd720039a846332cc62ee18d37"
#         ],
#         "title": "Delete test.txt",
#         "message": "Delete test.txt",
#         "author_name": "Kyle Thomas",
#         "author_email": "2548971t@student.gla.ac.uk",
#         "authored_date": "2022-09-28T12:11:27.000+01:00",
#         "committer_name": "Kyle Thomas",
#         "committer_email": "2548971t@student.gla.ac.uk",
#         "committed_date": "2022-09-28T12:11:27.000+01:00",
#         "trailers": {},
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2022/sh19/sh19-main/-/commit/53fa19286469613534f55e3691e9bc7dc87c4437"
#     },
#     {
#         "id": "7bef5e697d7ed2cd720039a846332cc62ee18d37",
#         "short_id": "7bef5e69",
#         "created_at": "2022-09-28T12:10:11.000+01:00",
#         "parent_ids": [
#             "0f8fd18716c542bce45821dbfbc89eb08da3493e"
#         ],
#         "title": "testing",
#         "message": "testing\n",
#         "author_name": "kylethmas",
#         "author_email": "kyle2010thomas@gmail.com",
#         "authored_date": "2022-09-28T12:10:11.000+01:00",
#         "committer_name": "kylethmas",
#         "committer_email": "kyle2010thomas@gmail.com",
#         "committed_date": "2022-09-28T12:10:11.000+01:00",
#         "trailers": {},
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2022/sh19/sh19-main/-/commit/7bef5e697d7ed2cd720039a846332cc62ee18d37"
#     },
#     {
#         "id": "0f8fd18716c542bce45821dbfbc89eb08da3493e",
#         "short_id": "0f8fd187",
#         "created_at": "2022-09-21T22:54:27.000+01:00",
#         "parent_ids": [],
#         "title": "Initial commit",
#         "message": "Initial commit",
#         "author_name": "Jiarui Li",
#         "author_email": "2530735l@student.gla.ac.uk",
#         "authored_date": "2022-09-21T22:54:27.000+01:00",
#         "committer_name": "Jiarui Li",
#         "committer_email": "2530735l@student.gla.ac.uk",
#         "committed_date": "2022-09-21T22:54:27.000+01:00",
#         "trailers": {},
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2022/sh19/sh19-main/-/commit/0f8fd18716c542bce45821dbfbc89eb08da3493e"
#     }
# ]

# %%
import requests
import json


def get_all_projects(search_term):    
    ids = []
    for i in range(100):
        url = f"https://stgit.dcs.gla.ac.uk/api/v4//users?page={i}&search={search_term}"
        response = requests.get(url, headers=headers)
        
        data = response.json()
        
        
        for i in response.json():
            print(f"{i.get('id')}: {i.get('full_path')}")
            
            proj_url = f"https://stgit.dcs.gla.ac.uk/api/v4//users/{i.get('id')}/projects"
            res = requests.get(proj_url, headers=headers).json()
           
            if res:
                ids += [proj.get("id") for proj in res]
            
                for i in res:
                    print(f"    {i.get('id')}: {i.get('name')}")
            
            
            
        if not response.headers.get("x-next-page"): return ids
        
    return ids
        
print(get_all_projects("team-project-h"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ln/18zrhm_n1b79bm28bhrknswm0000gn/T/ipykernel_4005/3464304102.py in <module>
#      30     return ids
#      31
# ---> 32 print(get_all_projects("team-project-h"))
#
# /var/folders/ln/18zrhm_n1b79bm28bhrknswm0000gn/T/ipykernel_4005/3464304102.py in get_all_projects(search_term)
#       7     for i in range(100):
#       8         url = f"https://stgit.dcs.gla.ac.uk/api/v4//users?page={i}&search={search_term}"
# ----> 9         response = requests.get(url, headers=headers)
#      10
#      11         data = response.json()
#
# NameError: name 'headers' is not defined

# %%
url = f"https://stgit.dcs.gla.ac.uk/api/v4//projects/2413/issues"
response = requests.get(url, headers=headers)
print(response.headers.get("x-next-page") == '')
print(json.dumps(response.json(), indent=4))
# Out:
# False
# [
#     {
#         "id": 20650,
#         "iid": 62,
#         "project_id": 2413,
#         "title": "Upgrade Django to 3.2",
#         "description": "",
#         "state": "closed",
#         "created_at": "2022-03-09T16:50:32.179+00:00",
#         "updated_at": "2022-03-15T16:07:06.673+00:00",
#         "closed_at": "2022-03-15T16:07:06.665+00:00",
#         "closed_by": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "labels": [
#             "Enhancement"
#         ],
#         "milestone": {
#             "id": 1384,
#             "iid": 6,
#             "project_id": 2413,
#             "title": "Iteration 6",
#             "description": "",
#             "state": "active",
#             "created_at": "2021-10-19T18:21:37.170+01:00",
#             "updated_at": "2022-02-16T16:42:47.470+00:00",
#             "due_date": "2022-03-18",
#             "start_date": "2022-02-16",
#             "expired": true,
#             "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/milestones/6"
#         },
#         "assignees": [
#             {
#                 "id": 1933,
#                 "username": "2458150o",
#                 "name": "Callum Ormond",
#                 "state": "active",
#                 "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#                 "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#             }
#         ],
#         "author": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "type": "ISSUE",
#         "assignee": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/62",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 0,
#             "completed_count": 0
#         },
#         "has_tasks": false,
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/62",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/62/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/62/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#62",
#             "relative": "#62",
#             "full": "team-project-h/2021/cs20/cs20-main#62"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 20561,
#         "iid": 61,
#         "project_id": 2413,
#         "title": "HttpError 503",
#         "description": "<!--\nNote: Please search to see if an issue already exists for the bug you encountered.\n-->\n\n#### Priority/Severity:\n\n- [x] **High** (Impacts the normal user flow or blocks app usage)\n- [ ] **Medium** (Negatively affects the user experience)\n- [ ] **Low** (Typos, missing icons, layout issues, etc.)\n\n## Current Behavior:\nExtract from https://dom-pubs.onlinelibrary.wiley.com/doi/10.1111/dom.14590 worked before. However, when I try to extract from it this week, it gives Error 503 Server Error: Service Temporarily Unavailable. I am not sure the website prevent from scraping or just prevent from scraping for my IP address\n\n\n## Expected Behavior:\nSuccessfully extract or address 503 error",
#         "state": "closed",
#         "created_at": "2022-03-09T13:20:23.984+00:00",
#         "updated_at": "2022-03-18T14:30:20.208+00:00",
#         "closed_at": "2022-03-18T14:30:20.199+00:00",
#         "closed_by": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "labels": [],
#         "milestone": null,
#         "assignees": [],
#         "author": {
#             "id": 1858,
#             "username": "2572194l",
#             "name": "Chuxiang Luo",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/c03d873af4d3e6cadd6267aba3414f0d?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2572194l"
#         },
#         "type": "ISSUE",
#         "assignee": null,
#         "user_notes_count": 1,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/61",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/61",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/61/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/61/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#61",
#             "relative": "#61",
#             "full": "team-project-h/2021/cs20/cs20-main#61"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 20277,
#         "iid": 60,
#         "project_id": 2413,
#         "title": "PDFs could be stored with the same nae",
#         "description": "<!--\nNote: Please search to see if an issue already exists for the bug you encountered.\n-->\n\n#### Priority/Severity:\n\n- [ ] **High** (Impacts the normal user flow or blocks app usage)\n- [x] **Medium** (Negatively affects the user experience)\n- [ ] **Low** (Typos, missing icons, layout issues, etc.)\n\n## Current Behavior:\n<!-- A concise description of what you're experiencing. -->\nThere is a small chance that different pdfs can be saved using the same name.\nHence the system will replace the older pdf file, even if the pdfs are different.\n\n### Steps to Reproduce\n<!--\nExample: steps to reproduce the behaviour:\n1. In this environment...\n2. With this config...\n3. Run '...'\n4. See error...\n-->\nUse the extension on two different pdfs but with the same name\n\n## Expected Behavior:\n<!-- A concise description of what you expected to happen. -->\nThe system should save each pdf as different files\n\n\n#### Anything else:\n<!--\nLinks? References? Anything that will give us more context about the issue that you are encountering!\n-->",
#         "state": "closed",
#         "created_at": "2022-03-02T14:07:44.941+00:00",
#         "updated_at": "2022-03-02T17:24:57.207+00:00",
#         "closed_at": "2022-03-02T14:08:47.006+00:00",
#         "closed_by": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "labels": [],
#         "milestone": null,
#         "assignees": [
#             {
#                 "id": 1969,
#                 "username": "2402884g",
#                 "name": "David Greco",
#                 "state": "active",
#                 "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#                 "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#             }
#         ],
#         "author": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "type": "ISSUE",
#         "assignee": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/60",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/60",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/60/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/60/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#60",
#             "relative": "#60",
#             "full": "team-project-h/2021/cs20/cs20-main#60"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 20270,
#         "iid": 59,
#         "project_id": 2413,
#         "title": "1 counts as invalid input",
#         "description": "<!--\nNote: Please search to see if an issue already exists for the bug you encountered.\n-->\n\n#### Priority/Severity:\n\n- [x] **High** (Impacts the normal user flow or blocks app usage)\n- [ ] **Medium** (Negatively affects the user experience)\n- [ ] **Low** (Typos, missing icons, layout issues, etc.)\n\n## Current Behavior:\n<!-- A concise description of what you're experiencing. -->\n1 counts as invalid input\n\n### Steps to Reproduce\n<!--\nExample: steps to reproduce the behaviour:\n1. In this environment...\n2. With this config...\n3. Run '...'\n4. See error...\n-->\nIf 1 is inserted as the input, you'll get an \"Invalid Input\" error\n\n## Expected Behavior:\n<!-- A concise description of what you expected to happen. -->\nIt should redirect to the preview of the tables on page 1\n\n#### Anything else:\n<!--\nLinks? References? Anything that will give us more context about the issue that you are encountering!\n-->",
#         "state": "closed",
#         "created_at": "2022-03-02T13:27:37.966+00:00",
#         "updated_at": "2022-03-02T17:24:57.188+00:00",
#         "closed_at": "2022-03-02T13:55:12.116+00:00",
#         "closed_by": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "labels": [
#             "Bug"
#         ],
#         "milestone": null,
#         "assignees": [
#             {
#                 "id": 1969,
#                 "username": "2402884g",
#                 "name": "David Greco",
#                 "state": "active",
#                 "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#                 "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#             }
#         ],
#         "author": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "type": "ISSUE",
#         "assignee": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/59",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/59",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/59/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/59/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#59",
#             "relative": "#59",
#             "full": "team-project-h/2021/cs20/cs20-main#59"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 20268,
#         "iid": 58,
#         "project_id": 2413,
#         "title": "Frontend Test",
#         "description": "\n#### Priority/Severity:\n\n\n- [x] **Low** (Trivial, minor improvements) \n\n## Current Behavior:\nTest for the popup, only the HTML popup and Js file - popup.js and background.js\n\n## Proposed Improvement:\nEither manually testing with documentation of some tests \n\n\n### Anything else:\nCould be omitted",
#         "state": "closed",
#         "created_at": "2022-03-02T13:10:15.524+00:00",
#         "updated_at": "2022-03-09T11:45:19.607+00:00",
#         "closed_at": "2022-03-09T11:45:19.596+00:00",
#         "closed_by": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "labels": [
#             "Feature"
#         ],
#         "milestone": {
#             "id": 1384,
#             "iid": 6,
#             "project_id": 2413,
#             "title": "Iteration 6",
#             "description": "",
#             "state": "active",
#             "created_at": "2021-10-19T18:21:37.170+01:00",
#             "updated_at": "2022-02-16T16:42:47.470+00:00",
#             "due_date": "2022-03-18",
#             "start_date": "2022-02-16",
#             "expired": true,
#             "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/milestones/6"
#         },
#         "assignees": [],
#         "author": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "type": "ISSUE",
#         "assignee": null,
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/58",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 1,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 1 checklist item completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/58",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/58/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/58/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#58",
#             "relative": "#58",
#             "full": "team-project-h/2021/cs20/cs20-main#58"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 20226,
#         "iid": 57,
#         "project_id": 2413,
#         "title": "enable/disable the addition of footnotes",
#         "description": "\n\n#### Priority/Severity:\n\n- [x] **Medium** (Good increase in performance/productivity/usability)\n\n\n## Problem/Motivation:\nEnable/disable the addition of the footnotes of a HTML table into the cell itself \n\n## Proposed Solution:\nusing option system and the checkbox in popup, and if statement in the HTML extraction script\n\n\n### Anything else:",
#         "state": "closed",
#         "created_at": "2022-03-01T13:14:44.576+00:00",
#         "updated_at": "2022-03-08T15:15:36.488+00:00",
#         "closed_at": "2022-03-08T15:15:36.482+00:00",
#         "closed_by": {
#             "id": 1858,
#             "username": "2572194l",
#             "name": "Chuxiang Luo",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/c03d873af4d3e6cadd6267aba3414f0d?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2572194l"
#         },
#         "labels": [
#             "Feature"
#         ],
#         "milestone": {
#             "id": 1384,
#             "iid": 6,
#             "project_id": 2413,
#             "title": "Iteration 6",
#             "description": "",
#             "state": "active",
#             "created_at": "2021-10-19T18:21:37.170+01:00",
#             "updated_at": "2022-02-16T16:42:47.470+00:00",
#             "due_date": "2022-03-18",
#             "start_date": "2022-02-16",
#             "expired": true,
#             "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/milestones/6"
#         },
#         "assignees": [
#             {
#                 "id": 1858,
#                 "username": "2572194l",
#                 "name": "Chuxiang Luo",
#                 "state": "active",
#                 "avatar_url": "https://secure.gravatar.com/avatar/c03d873af4d3e6cadd6267aba3414f0d?s=80&d=identicon",
#                 "web_url": "https://stgit.dcs.gla.ac.uk/2572194l"
#             }
#         ],
#         "author": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "type": "ISSUE",
#         "assignee": {
#             "id": 1858,
#             "username": "2572194l",
#             "name": "Chuxiang Luo",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/c03d873af4d3e6cadd6267aba3414f0d?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2572194l"
#         },
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/57",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 1,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 1 checklist item completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/57",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/57/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/57/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#57",
#             "relative": "#57",
#             "full": "team-project-h/2021/cs20/cs20-main#57"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 20225,
#         "iid": 56,
#         "project_id": 2413,
#         "title": "Fix popup checkboxes",
#         "description": "<!--\nNote: Please search to see if an issue already exists for the bug you encountered.\n-->\n\n#### Priority/Severity:\n\n\n- [x] **Medium** (Negatively affects the user experience)\n\n\n## Current Behavior:\noption2 can only update to the current state of option2 \n\n\n\n## Expected Behavior:\n<!-- A concise description of what you expected to happen. -->\n\n\n\n#### Anything else:\nupdate independently",
#         "state": "closed",
#         "created_at": "2022-03-01T13:12:33.497+00:00",
#         "updated_at": "2022-03-08T12:59:37.154+00:00",
#         "closed_at": "2022-03-08T12:59:37.141+00:00",
#         "closed_by": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "labels": [
#             "Bug"
#         ],
#         "milestone": {
#             "id": 1384,
#             "iid": 6,
#             "project_id": 2413,
#             "title": "Iteration 6",
#             "description": "",
#             "state": "active",
#             "created_at": "2021-10-19T18:21:37.170+01:00",
#             "updated_at": "2022-02-16T16:42:47.470+00:00",
#             "due_date": "2022-03-18",
#             "start_date": "2022-02-16",
#             "expired": true,
#             "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/milestones/6"
#         },
#         "assignees": [
#             {
#                 "id": 1933,
#                 "username": "2458150o",
#                 "name": "Callum Ormond",
#                 "state": "active",
#                 "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#                 "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#             }
#         ],
#         "author": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "type": "ISSUE",
#         "assignee": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/56",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 1,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 1 checklist item completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/56",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/56/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/56/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#56",
#             "relative": "#56",
#             "full": "team-project-h/2021/cs20/cs20-main#56"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 20069,
#         "iid": 55,
#         "project_id": 2413,
#         "title": "Create Django Tests",
#         "description": "<!--\nNote: Please search to see if a similar issue already exists\n-->\n\n#### Priority/Severity:\n\n- [ ] **High** (Huge increase in performance/productivity/usability/legislative cover)\n- [x] **Medium** (Good increase in performance/productivity/usability)\n- [ ] **Low** (Trivial, minor improvements) \n\n## Problem/Motivation:\nThere aren't any implemented tests in Django\n\n## Proposed Solution:\nImplements tests for models, URLs and views\n\n\n### Anything else:",
#         "state": "closed",
#         "created_at": "2022-02-22T18:09:59.283+00:00",
#         "updated_at": "2022-02-22T18:10:08.106+00:00",
#         "closed_at": "2022-02-22T18:10:08.099+00:00",
#         "closed_by": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "labels": [],
#         "milestone": null,
#         "assignees": [
#             {
#                 "id": 1969,
#                 "username": "2402884g",
#                 "name": "David Greco",
#                 "state": "active",
#                 "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#                 "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#             }
#         ],
#         "author": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "type": "ISSUE",
#         "assignee": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/55",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/55",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/55/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/55/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#55",
#             "relative": "#55",
#             "full": "team-project-h/2021/cs20/cs20-main#55"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 19876,
#         "iid": 54,
#         "project_id": 2413,
#         "title": "Allow DOI to be pulled from webpage",
#         "description": "<!--\nNote: Please search to see if a similar issue already exists\n-->\n\n#### Priority/Severity:\n\n- [ ] **High** (Huge increase in performance/productivity/usability/legislative cover)\n- [x] **Medium** (Good increase in performance/productivity/usability)\n- [ ] **Low** (Trivial, minor improvements) \n\n## Problem/Motivation:\n<!-- A description of what the implementation lacks -->\nCurrently, a doi is only found through the URL, however, many papers don't include the doi in the url, but only in the html body.\n\n## Proposed Solution:\n<!-- A description of what you would like to add -->\nIf the url doesn't contain a doi, search for it in the html body.\n\n\n### Anything else:",
#         "state": "closed",
#         "created_at": "2022-02-17T13:41:00.804+00:00",
#         "updated_at": "2022-02-17T13:41:05.863+00:00",
#         "closed_at": "2022-02-17T13:41:05.856+00:00",
#         "closed_by": {
#             "id": 1895,
#             "username": "2468915d",
#             "name": "Aidan Dow",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/945885382028b6723899f162d6af54fd?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2468915d"
#         },
#         "labels": [],
#         "milestone": null,
#         "assignees": [],
#         "author": {
#             "id": 1895,
#             "username": "2468915d",
#             "name": "Aidan Dow",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/945885382028b6723899f162d6af54fd?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2468915d"
#         },
#         "type": "ISSUE",
#         "assignee": null,
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/54",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/54",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/54/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/54/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#54",
#             "relative": "#54",
#             "full": "team-project-h/2021/cs20/cs20-main#54"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 19819,
#         "iid": 53,
#         "project_id": 2413,
#         "title": "Implement a cyclic db cleaning process",
#         "description": "<!--\nNote: Please search to see if a similar issue already exists\n-->\n\n#### Priority/Severity:\n\n- [ ] **High** (Huge increase in performance/productivity/usability/legislative cover)\n- [x] **Medium** (Good increase in performance/productivity/usability)\n- [ ] **Low** (Trivial, minor improvements) \n\n## Problem/Motivation:\nCurrently, the DB removes records only if the MAX_ENTRIES number is reached.\nHowever, it does not remove records based on time. \n\nThis means that, probably, a stored URL request won't be processed again, giving incorrect information in case the URL content has been updated.\n\n## Proposed Solution:\nA cyclic cleaning process that removes entries based on time.\nThis way records older than a specified threshold are removed and thus re-processed the next time they are requested again.\n\n### Anything else:",
#         "state": "closed",
#         "created_at": "2022-02-16T17:40:58.838+00:00",
#         "updated_at": "2022-02-16T17:41:03.425+00:00",
#         "closed_at": "2022-02-16T17:41:03.417+00:00",
#         "closed_by": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "labels": [],
#         "milestone": null,
#         "assignees": [
#             {
#                 "id": 1969,
#                 "username": "2402884g",
#                 "name": "David Greco",
#                 "state": "active",
#                 "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#                 "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#             }
#         ],
#         "author": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "type": "ISSUE",
#         "assignee": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/53",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/53",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/53/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/53/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#53",
#             "relative": "#53",
#             "full": "team-project-h/2021/cs20/cs20-main#53"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 19710,
#         "iid": 52,
#         "project_id": 2413,
#         "title": "Selecting \"all\" pages on pdf causes error",
#         "description": "<!--\nNote: Please search to see if an issue already exists for the bug you encountered.\n-->\n\n#### Priority/Severity:\n\n- [x] **High** (Impacts the normal user flow or blocks app usage)\n- [ ] **Medium** (Negatively affects the user experience)\n- [ ] **Low** (Typos, missing icons, layout issues, etc.)\n\n## Current Behavior:\n<!-- A concise description of what you're experiencing. -->\nWhen all pages are selected in a pdf to extract from, the server throws an error\n\n### Steps to Reproduce\n<!--\nExample: steps to reproduce the behavior:\n1. In this environment...\n2. With this config...\n3. Run '...'\n4. See error...\n-->\n1. Go to any pdf, here is an example: http://www.uncledavesenterprise.com/file/health/Food%20Calories%20List.pdf\n\n2. Right click on the table and click Streamline Table\n\n3. Leave the dialogue box with the default \"all\" selected\n\n4. You will encounter an error :( \n\n## Expected Behavior:\n<!-- A concise description of what you expected to happen. -->\nSelecting \"all\" pages should function correctly\n\n\n\n#### Anything else:\n<!--\nLinks? References? Anything that will give us more context about the issue that you are encountering!\n-->",
#         "state": "closed",
#         "created_at": "2022-02-16T12:53:33.651+00:00",
#         "updated_at": "2022-03-02T17:24:57.238+00:00",
#         "closed_at": "2022-02-16T18:27:30.670+00:00",
#         "closed_by": {
#             "id": 1969,
#             "username": "2402884g",
#             "name": "David Greco",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/61a502517269698d8705cf946ede968e?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2402884g"
#         },
#         "labels": [],
#         "milestone": null,
#         "assignees": [],
#         "author": {
#             "id": 1895,
#             "username": "2468915d",
#             "name": "Aidan Dow",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/945885382028b6723899f162d6af54fd?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2468915d"
#         },
#         "type": "ISSUE",
#         "assignee": null,
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/52",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/52",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/52/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/52/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#52",
#             "relative": "#52",
#             "full": "team-project-h/2021/cs20/cs20-main#52"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 19709,
#         "iid": 51,
#         "project_id": 2413,
#         "title": "SSL Error on some sites",
#         "description": "\n#### Priority/Severity:\n\n- [ ] **High** (Impacts the normal user flow or blocks app usage)\n- [x] **Medium** (Negatively affects the user experience)\n- [ ] **Low** (Typos, missing icons, layout issues, etc.)\n\n## Current Behavior:\nGives errors on some sites.\n\n### Steps to Reproduce\nRun-on this site - https://www.scirp.org/journal/paperinformation.aspx?paperid=115227\n\n## Expected Behavior:\nProcess table normally",
#         "state": "closed",
#         "created_at": "2022-02-16T12:52:31.297+00:00",
#         "updated_at": "2022-03-02T12:44:04.843+00:00",
#         "closed_at": "2022-03-02T12:44:04.835+00:00",
#         "closed_by": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "labels": [
#             "Customer Presentation"
#         ],
#         "milestone": {
#             "id": 1384,
#             "iid": 6,
#             "project_id": 2413,
#             "title": "Iteration 6",
#             "description": "",
#             "state": "active",
#             "created_at": "2021-10-19T18:21:37.170+01:00",
#             "updated_at": "2022-02-16T16:42:47.470+00:00",
#             "due_date": "2022-03-18",
#             "start_date": "2022-02-16",
#             "expired": true,
#             "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/milestones/6"
#         },
#         "assignees": [],
#         "author": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "type": "ISSUE",
#         "assignee": null,
#         "user_notes_count": 1,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/51",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/51",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/51/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/51/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#51",
#             "relative": "#51",
#             "full": "team-project-h/2021/cs20/cs20-main#51"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 19708,
#         "iid": 50,
#         "project_id": 2413,
#         "title": "Get server up and running",
#         "description": "\n#### Priority/Severity:\n\n- [x] **High** (Huge increase in performance/productivity/usability/legislative cover)\n- [ ] **Medium** (Good increase in performance/productivity/usability)\n- [ ] **Low** (Trivial, minor improvements) \n\n## Problem/Motivation:\n - Contact Jesus to get more information on the server and the set-up process \n - Need to decide how the server will be hosted, locally on their server, or public on their server \n - jesus.rodriguezperez@glasgow.ac.uk",
#         "state": "closed",
#         "created_at": "2022-02-16T12:49:14.330+00:00",
#         "updated_at": "2022-03-18T14:34:59.596+00:00",
#         "closed_at": "2022-03-18T14:34:59.586+00:00",
#         "closed_by": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "labels": [
#             "Customer Presentation"
#         ],
#         "milestone": {
#             "id": 1384,
#             "iid": 6,
#             "project_id": 2413,
#             "title": "Iteration 6",
#             "description": "",
#             "state": "active",
#             "created_at": "2021-10-19T18:21:37.170+01:00",
#             "updated_at": "2022-02-16T16:42:47.470+00:00",
#             "due_date": "2022-03-18",
#             "start_date": "2022-02-16",
#             "expired": true,
#             "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/milestones/6"
#         },
#         "assignees": [],
#         "author": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "type": "ISSUE",
#         "assignee": null,
#         "user_notes_count": 1,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/50",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
# ...
#             "state": "active",
#             "created_at": "2021-10-19T18:21:37.170+01:00",
#             "updated_at": "2022-02-16T16:42:47.470+00:00",
#             "due_date": "2022-03-18",
#             "start_date": "2022-02-16",
#             "expired": true,
#             "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/milestones/6"
#         },
#         "assignees": [],
#         "author": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "type": "ISSUE",
#         "assignee": null,
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/47",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/47",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/47/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/47/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#47",
#             "relative": "#47",
#             "full": "team-project-h/2021/cs20/cs20-main#47"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 19697,
#         "iid": 46,
#         "project_id": 2413,
#         "title": "Finalise UI",
#         "description": "#### Priority/Severity:\n\n- [ ] **High** (Huge increase in performance/productivity/usability/legislative cover)\n- [ ] **Medium** (Good increase in performance/productivity/usability)\n- [x] **Low** (Trivial, minor improvements) \n\n## Problem/Motivation:\nMake sure the UI is looking and working for the final version",
#         "state": "closed",
#         "created_at": "2022-02-16T12:31:17.870+00:00",
#         "updated_at": "2022-03-02T13:15:28.053+00:00",
#         "closed_at": "2022-03-02T13:15:28.046+00:00",
#         "closed_by": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "labels": [
#             "Customer Presentation"
#         ],
#         "milestone": {
#             "id": 1384,
#             "iid": 6,
#             "project_id": 2413,
#             "title": "Iteration 6",
#             "description": "",
#             "state": "active",
#             "created_at": "2021-10-19T18:21:37.170+01:00",
#             "updated_at": "2022-02-16T16:42:47.470+00:00",
#             "due_date": "2022-03-18",
#             "start_date": "2022-02-16",
#             "expired": true,
#             "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/milestones/6"
#         },
#         "assignees": [],
#         "author": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "type": "ISSUE",
#         "assignee": null,
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/46",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/46",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/46/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/46/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#46",
#             "relative": "#46",
#             "full": "team-project-h/2021/cs20/cs20-main#46"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 19696,
#         "iid": 45,
#         "project_id": 2413,
#         "title": "Make the system resilient to errors",
#         "description": "#### Priority/Severity:\n\n- [ ] **High** (Huge increase in performance/productivity/usability/legislative cover)\n- [ ] **Medium** (Good increase in performance/productivity/usability)\n- [ ] **Low** (Trivial, minor improvements) \n\n## Current Behavior:\n\n\n## Proposed Improvement:\nCheck with the test suite to fix edge cases and make sure the server doesn't crash \n\n\n### Anything else:",
#         "state": "closed",
#         "created_at": "2022-02-16T12:29:12.081+00:00",
#         "updated_at": "2022-03-09T11:45:11.261+00:00",
#         "closed_at": "2022-03-09T11:45:11.252+00:00",
#         "closed_by": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "labels": [
#             "Customer Presentation"
#         ],
#         "milestone": {
#             "id": 1384,
#             "iid": 6,
#             "project_id": 2413,
#             "title": "Iteration 6",
#             "description": "",
#             "state": "active",
#             "created_at": "2021-10-19T18:21:37.170+01:00",
#             "updated_at": "2022-02-16T16:42:47.470+00:00",
#             "due_date": "2022-03-18",
#             "start_date": "2022-02-16",
#             "expired": true,
#             "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/milestones/6"
#         },
#         "assignees": [],
#         "author": {
#             "id": 1933,
#             "username": "2458150o",
#             "name": "Callum Ormond",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/b2f448c5f8775b70c70f4766ed7559a7?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2458150o"
#         },
#         "type": "ISSUE",
#         "assignee": null,
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/45",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 0
#         },
#         "has_tasks": true,
#         "task_status": "0 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/45",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/45/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/45/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#45",
#             "relative": "#45",
#             "full": "team-project-h/2021/cs20/cs20-main#45"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 19532,
#         "iid": 44,
#         "project_id": 2413,
#         "title": "Download CSV file instead of zip when single table is selected",
#         "description": "<!--\nNote: Please search to see if a similar issue already exists\n-->\n\n#### Priority/Severity:\n\n- [ ] **High** (Huge increase in performance/productivity/usability/legislative cover)\n- [x] **Medium** (Good increase in performance/productivity/usability)\n- [ ] **Low** (Trivial, minor improvements) \n\n## Problem/Motivation:\n<!-- A description of what the implementation lacks -->\nCurrently, the program downloads a zip of whatever is selected, be that a singular file or all of them\n\n## Proposed Solution:\n<!-- A description of what you would like to add -->\nIf the user chooses to download a single table, it will download as a csv instead of a zip\n\n### Anything else:",
#         "state": "closed",
#         "created_at": "2022-02-09T12:07:32.141+00:00",
#         "updated_at": "2022-02-09T12:12:13.191+00:00",
#         "closed_at": "2022-02-09T12:09:38.250+00:00",
#         "closed_by": {
#             "id": 1895,
#             "username": "2468915d",
#             "name": "Aidan Dow",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/945885382028b6723899f162d6af54fd?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2468915d"
#         },
#         "labels": [],
#         "milestone": null,
#         "assignees": [],
#         "author": {
#             "id": 1895,
#             "username": "2468915d",
#             "name": "Aidan Dow",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/945885382028b6723899f162d6af54fd?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2468915d"
#         },
#         "type": "ISSUE",
#         "assignee": null,
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/44",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/44",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/44/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/44/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#44",
#             "relative": "#44",
#             "full": "team-project-h/2021/cs20/cs20-main#44"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     },
#     {
#         "id": 19518,
#         "iid": 43,
#         "project_id": 2413,
#         "title": "Replacing selenium",
#         "description": "#### Priority/Severity:\n\n- [ ] **High** (Impacts the normal user flow or blocks app usage)\n- [x] **Medium** (Negatively affects the user experience)\n- [ ] **Low** (Typos, missing icons, layout issues, etc.)\n\n## Current Behavior:\nPythonanywhere don't support the lastest version of selenium. In order to avoid this and other problems possibly caused by selenium, replacing selenium and web driver with requests and beautifulsoup\n\n## Expected Behavior:\nhtml_to_csv.py can work successfully on server",
#         "state": "closed",
#         "created_at": "2022-02-09T00:31:30.966+00:00",
#         "updated_at": "2022-02-09T08:49:23.860+00:00",
#         "closed_at": "2022-02-09T08:49:23.854+00:00",
#         "closed_by": {
#             "id": 1858,
#             "username": "2572194l",
#             "name": "Chuxiang Luo",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/c03d873af4d3e6cadd6267aba3414f0d?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2572194l"
#         },
#         "labels": [],
#         "milestone": null,
#         "assignees": [
#             {
#                 "id": 1858,
#                 "username": "2572194l",
#                 "name": "Chuxiang Luo",
#                 "state": "active",
#                 "avatar_url": "https://secure.gravatar.com/avatar/c03d873af4d3e6cadd6267aba3414f0d?s=80&d=identicon",
#                 "web_url": "https://stgit.dcs.gla.ac.uk/2572194l"
#             }
#         ],
#         "author": {
#             "id": 1858,
#             "username": "2572194l",
#             "name": "Chuxiang Luo",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/c03d873af4d3e6cadd6267aba3414f0d?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2572194l"
#         },
#         "type": "ISSUE",
#         "assignee": {
#             "id": 1858,
#             "username": "2572194l",
#             "name": "Chuxiang Luo",
#             "state": "active",
#             "avatar_url": "https://secure.gravatar.com/avatar/c03d873af4d3e6cadd6267aba3414f0d?s=80&d=identicon",
#             "web_url": "https://stgit.dcs.gla.ac.uk/2572194l"
#         },
#         "user_notes_count": 0,
#         "merge_requests_count": 0,
#         "upvotes": 0,
#         "downvotes": 0,
#         "due_date": null,
#         "confidential": false,
#         "discussion_locked": null,
#         "issue_type": "issue",
#         "web_url": "https://stgit.dcs.gla.ac.uk/team-project-h/2021/cs20/cs20-main/-/issues/43",
#         "time_stats": {
#             "time_estimate": 0,
#             "total_time_spent": 0,
#             "human_time_estimate": null,
#             "human_total_time_spent": null
#         },
#         "task_completion_status": {
#             "count": 3,
#             "completed_count": 1
#         },
#         "has_tasks": true,
#         "task_status": "1 of 3 checklist items completed",
#         "_links": {
#             "self": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/43",
#             "notes": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/43/notes",
#             "award_emoji": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413/issues/43/award_emoji",
#             "project": "https://stgit.dcs.gla.ac.uk/api/v4/projects/2413",
#             "closed_as_duplicate_of": null
#         },
#         "references": {
#             "short": "#43",
#             "relative": "#43",
#             "full": "team-project-h/2021/cs20/cs20-main#43"
#         },
#         "severity": "UNKNOWN",
#         "moved_to_id": null,
#         "service_desk_reply_to": null
#     }
# ]

# %%
get_url(2413, "")
# Out:
# 'https://stgit.dcs.gla.ac.uk/api/v4//projects/2413/'

# %%
import json, datetime
import matplotlib.pyplot as plt

def get_num_pages(id, per_page):
    i = 1
    while True:
        response = get_commits_page(id, i, per_page)
        if not response.headers.get("x-next-page"): return i
        i+=1
        
def get_commits_page(id, page, per_page):
    url = get_url(id, f"repository/commits?per_page={per_page}&page={page}")
    response = requests.get(url, headers=headers)
#     print(json.dumps(dict(response.headers), indent=4))
    return response

def get_num_commits(id, per_page):

    t1 = datetime.datetime.now()

    full_pages = get_num_pages(id, per_page)
    last_page = get_commits_page(id, full_pages, per_page)
    
    total = ((full_pages-1) * per_page) + len(last_page.json())
    # print(last_page.json())

    t2 = datetime.datetime.now()
    
    time_taken = float(f"{(t2-t1).seconds}.{(t2-t1).microseconds}")

    print(f"per_page: {per_page}")
    print(f"Pages full = {full_pages-1}, last_page = {len(last_page.json())}")
    print(f"Total size = {total}")
    print(f"Time Taken: {time_taken}s")
    print()
    return time_taken
    
times = []
per_pages = [40, 50, 60,70,80,90,100]
for per_page in per_pages:
    times.append(get_num_commits(2413, per_page))
    
plt.plot(per_pages, times)
# Out:
# per_page: 40
# Pages full = 6, last_page = 23
# Total size = 263
# Time Taken: 2.92291s
#
# per_page: 50
# Pages full = 5, last_page = 13
# Total size = 263
# Time Taken: 1.840495s
#
# per_page: 60
# Pages full = 4, last_page = 23
# Total size = 263
# Time Taken: 1.638272s
#
# per_page: 70
# Pages full = 3, last_page = 53
# Total size = 263
# Time Taken: 1.457951s
#
# per_page: 80
# Pages full = 3, last_page = 23
# Total size = 263
# Time Taken: 1.431923s
#
# per_page: 90
# Pages full = 2, last_page = 83
# Total size = 263
# Time Taken: 1.156308s
#
# per_page: 100
# Pages full = 2, last_page = 63
# Total size = 263
# Time Taken: 1.182334s
